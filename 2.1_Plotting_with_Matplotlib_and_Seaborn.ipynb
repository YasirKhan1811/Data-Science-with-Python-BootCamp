# %% [markdown]
# # - BMI Calculator

# %%
# body mass index
# input weight
# input height
# BMI
# Calculate BMI
# print BMI (My name is ...., and my BMI is ....)

# %%
height = input("What is your height? ")
# Out:
# What is your height? 1.85

# %%
height = float(height)

# %%
weight = input("What is your weight? ")
# Out:
# What is your weight? 90

# %%
weight = int(weight)

# %%
name = input("What is your name? ")
# Out:
# What is your name? Yasir

# %%
# formula for BMI: weight/height**2
BMI = weight/(height**2)
print("I am", name, ".", "My height is", height, "m", "and","my weight is", weight, "kgs" ".", "Hence my BMI will be", BMI, ".")
# Out:
# I am Yasir . My height is 1.85 m and my weight is 90 kgs. Hence my BMI will be 26.296566837107374 .

# %% [markdown]
# # - Fundamentals of Visualization
#
# **Data, Code and Graph Traiangle**
#
# What is grammer of graphics?
#
# Major parts:
# - Mapping (Data)
# - Aesthetic (color, shape, size)
# - Geometric (objects: Line, Bar, Points, Box, Map)
#
# "Work like an Artist or Be a Copycat" - babaAammar

# %% [markdown]
# # - Bar plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
sns.catplot(x = "sex", y = "survived", hue = "class", kind = "bar", data = titanic)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
p1=sns.countplot(x = "sex", data = titanic, hue = "class")
p1.set_title("Plot for Couting")
# Out:
# Text(0.5, 1.0, 'Plot for Couting')

# %% [markdown]
# # - Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row = "sex", hue = "alone")
g=(g.map(plt.scatter, "age", "fare").add_legend())
