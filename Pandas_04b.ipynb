# %% [markdown]
# ## Data Wrangling 02
#
# This part of data wrangling is about data cleaning (replacing NaN values). Primarily, the purpose is to replace categorical data values in columns with dummy values (i.e replacing male with 1 and female with 0 in the gender column) and also Binning is applied to the age column, where ages are grouped into categories.

# %% [markdown]
# Following are the steps of this tutorial:

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Load Titanic Dataset

# %%
kashti_1 = sns.load_dataset('titanic')
kashti_1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti_1.shape
# Out:
# (891, 15)

# %%
kashti_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# **Replacing NaN Values of Age with Mean Age**

# %%
mean = kashti_1['age'].mean()
mean
# Out:
# 29.69911764705882

# %%
kashti_1['age'] = kashti_1['age'].replace(np.nan, mean)
kashti_1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# **Replacing NaN Values of Categorical Columns (deck, embarked, and embark_town) with mode of each series**

# %%
columns = kashti_1.filter(['deck', 'embarked', 'embark_town'])
columns
# Out:
#     deck embarked  embark_town
# 0    NaN        S  Southampton
# 1      C        C    Cherbourg
# 2    NaN        S  Southampton
# 3      C        S  Southampton
# 4    NaN        S  Southampton
# ..   ...      ...          ...
# 886  NaN        S  Southampton
# 887    B        S  Southampton
# 888  NaN        S  Southampton
# 889    C        C    Cherbourg
# 890  NaN        Q   Queenstown
#
# [891 rows x 3 columns]

# %%
modes = columns.mode()
modes
# Out:
#   deck embarked  embark_town
# 0    C        S  Southampton

# %%
kashti_2 = kashti_1.fillna(kashti_1.mode().iloc[0])
kashti_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True    C  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False    C  Southampton   yes   True
# 3     First  woman       False    C  Southampton   yes  False
# 4     Third    man        True    C  Southampton    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 886  Second    man        True    C  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False    C  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True    C   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
kashti_2.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti_1.shape
# Out:
# (891, 15)

# %% [markdown]
# **Binning:**
# Grouping the values of age column into categories

# %%
bins = [1, 4, 12, 19, 39, 60, 100]
labels = ['Infant', 'Toddler', 'Child', 'Teens', 'Adults', 'Middle Age Adult'] 
kashti_2['age'] = pd.cut(kashti_2['age'], bins=bins, labels=labels)
kashti_2
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  Teens      1      0   7.2500        S   Third
# 1           1       1  female  Teens      1      0  71.2833        C   First
# 2           1       3  female  Teens      0      0   7.9250        S   Third
# 3           1       1  female  Teens      1      0  53.1000        S   First
# 4           0       3    male  Teens      0      0   8.0500        S   Third
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 886         0       2    male  Teens      0      0  13.0000        S  Second
# 887         1       1  female  Child      0      0  30.0000        S   First
# 888         0       3  female  Teens      1      2  23.4500        S   Third
# 889         1       1    male  Teens      0      0  30.0000        C   First
# 890         0       3    male  Teens      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True    C  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False    C  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True    C  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True    C  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False    C  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True    C   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# **Categorical Values into Dummies**

# %%
df = pd. get_dummies(kashti_2, columns=['sex']) 
df.head()
# Out:
#    survived  pclass    age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  Teens      1      0   7.2500        S  Third    man
# 1         1       1  Teens      1      0  71.2833        C  First  woman
# 2         1       3  Teens      0      0   7.9250        S  Third  woman
# 3         1       1  Teens      1      0  53.1000        S  First  woman
# 4         0       3  Teens      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  sex_female  sex_male
# 0        True    C  Southampton    no  False           0         1
# 1       False    C    Cherbourg   yes  False           1         0
# 2       False    C  Southampton   yes   True           1         0
# 3       False    C  Southampton   yes  False           1         0
# 4        True    C  Southampton    no   True           0         1
