# %% [markdown]
# # Chilla Data Visualization

# %%
# import pandas library to load our dataset
import pandas as pd

# %%
# loading chilla data
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")
chilla.head(4)
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# 2                        Zong             Prepaid  ...
# 3                      U-fone            Postpaid  ...
#
# ...

# %% [markdown]
# # Count Plots

# %%
# 1- imprort libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 2- import data from file
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 3- setting the Canvas
sns.set_theme(style="ticks", color_codes=True)

# 4- plot
p1 = sns.countplot(x = "Gender", data = chilla, 
                   palette="pastel", saturation=1)
plt.xlabel("Gender", size=14, weight="bold")
plt.ylabel("Count", size=14, weight="bold")
plt.title("Plot for Counting Chilla Participants", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Plot for Counting Chilla Participants')

# %% [markdown]
# *From this plot, it is concluded that the number of male participants in this chilla are up to 300 and the female participants are about 90.*

# %% [markdown]
# **The following countplot shows the numbers of male and female participants of this chilla based on their education completed.**

# %%
# 1- imprort libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 2- import data from file
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 3- setting the Canvas
sns.set_theme(style="ticks", color_codes=True)

# 4- plot
p1 = sns.countplot(x = "Qualification_completed", hue="Gender",
                   data = chilla, palette="pastel", saturation=1,
                   order=["Pre-Bachelors", "Bachelors", "Masters", "PhD"])
p1.set_title("Plot for Counting Chilla Participants Based on Qualification")

# 5- setting and sizing labels and title
plt.xlabel("Qualification_completed", size=14, weight="bold")
plt.ylabel("Count", size=14, weight="bold")
plt.title("Participants Based on Qualification", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Participants Based on Qualification')

# %% [markdown]
# **To know the Number of Participants Based on Where They Live?**

# %%
# 1- imprort libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 2- import data from file
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 3- setting the Canvas
sns.set_theme(style="ticks", color_codes=True)

# 4- plot
p1 = sns.countplot(x = "Gender", hue="Where do you live?", data = chilla, palette="pastel", saturation=1)
p1.set_title("Plot for Counting Chilla Participants")

# 5- setting and sizing labels and title
plt.xlabel("Gender", size=14, weight="bold")
plt.ylabel("Count", size=14, weight="bold")
plt.title("Participants Based on Where They Live?", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Participants Based on Where They Live?')

# %% [markdown]
# # Bar Plot

# %%
# 1- imprort libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 2- import data from file
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 3- setting the Canvas
sns.set_theme(style="ticks", color_codes=True)

# 4- size of figure
plt.figure(figsize=(10,6))
 
# 5- plot
p1 = sns.barplot(x = "How many hours you code a day? (int) e.g: 5,4,3", 
                 y="field_of_study", 
                 data = chilla, palette="Set2", saturation=1,
                 linewidth=1, ci=None, edgecolor="0.1")

# 6- setting and sizing labels and title
plt.xlabel("Coding (Hrs)", size=14, weight="bold")
plt.ylabel("Field of Study", size=14, weight="bold")
plt.title("Hours of Coding Based on Different Education Backgrounds", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Hours of Coding Based on Different Education Backgrounds')

# %% [markdown]
# # Box Plots

# %%
# 1- imprort libraries
import seaborn as sns
import pandas as pd

# 2- setting the Canvas
palette = {"Yes": "Grey", "No": "Purple"}

# 3- figure size
plt.figure(figsize=(10,6))

# 4- import data from file
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 5- Draw a boxplot
sns.boxplot(x="Research/Working experience (Float/Int) years", y="field_of_study", 
            palette="pastel",
            data=chilla)

# 6- setting axis limits and offset
plt.title("")
plt.xlim(-1,12)
sns.despine(offset=0, trim=False)

# 7- setting and sizing labels and title
plt.xlabel("Research/Working Experience", size=14, weight="bold")
plt.ylabel("Field of Study", size=14, weight="bold")
plt.title("Box Plot of Research Experience", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Box Plot of Research Experience')

# %%
# 1- import libraries

import seaborn as sns
import pandas as pd

# 2- setting theme
palette = {"Yes": "Yellow", "No": "Green"}

# 3- load the dataset
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 4- Draw a boxplot
sns.boxplot(x="How many hours you code a day? (int) e.g: 5,4,3", 
            y="What are you?", hue="Marital Status?", palette=palette,
            data=chilla, dodge=True)

# 5- offset and trim
sns.despine(offset=5, trim=False)

# 6- setting axis limits
plt.xlim(-1, 12)

# 7- setting and sizing labels and title
plt.xlabel("Research/Working Experience", size=14, weight="bold")
plt.ylabel("Field of Study", size=14, weight="bold")
plt.title("Daily Coding Hours as per the Employment Status", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Daily Coding Hours as per the Employment Status')

# %%
# 1- import libraries
import seaborn as sns
import pandas as pd

# 2- load dataset
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 3- Draw a boxplot
sns.boxplot(x="Marital Status?", y="Your Weight in kg? (float)", 
            hue="Gender", palette=("pastel"), data=chilla, saturation=1)

# 4- offset and trim
sns.despine(offset=0, trim=False)

# 5- setting axis limits
plt.ylim(30, 120)

# 6- setting and sizing labels and title
plt.xlabel("Marital Status", size=14, weight="bold")
plt.ylabel("Weight", size=14, weight="bold")
plt.title("Weight as Function of Matrital Status", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Weight as Function of Matrital Status')

# %%
# 1- import libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 2- setting theme
sns.set_theme(style="ticks", palette="pastel")

# 3-load the example tips dataset
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 4- plot
sns.boxplot(x=chilla["Height in cm? Freelancer- (Float)"])

# 5- axis limits
plt.xlim(130, 200)

# 6- setting and sizing labels and title
plt.xlabel("Height (cm)", size=14, weight="bold")
plt.title("Spread of Height of Chilla Participants", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Spread of Height of Chilla Participants')

# %% [markdown]
# # Line Plot

# %%
# 1- import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# 2- load dataset
chilla = pd.read_excel("chilla_data_cleaned.xlsx", "Sheet1")

# 2- draw a line plot
sns.lineplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3", data=chilla)

# 3- axis limits
plt.xlim(0, 24)
plt.ylim(0, 7)

# 4- setting and sizing labels and title
plt.xlabel("Light Kitni Der Band Hoti Hay", size=12, weight="bold")
plt.ylabel("Hours Spent Daily on Coding", size=12, weight="bold")
plt.title("Plot of Coding Hours", size=14, weight="bold")
# Out:
# Text(0.5, 1.0, 'Plot of Coding Hours')
